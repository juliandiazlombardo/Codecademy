# %% [markdown]
# # Hurricane Analysis

# %% [markdown]
# #### Overview

# %% [markdown]
# This project is slightly different than others you have encountered thus far. Instead of a step-by-step tutorial, this project contains a series of open-ended requirements which describe the project you'll be building. There are many possible ways to correctly fulfill all of these requirements, and you should expect to use the internet, Codecademy, and other resources when you encounter a problem that you cannot easily solve.

# %% [markdown]
# #### Project Goals

# %% [markdown]
# You will work to write several functions that organize and manipulate data about Category 5 Hurricanes, the strongest hurricanes as rated by their wind speed. Each one of these functions will use a number of parameters, conditionals, lists, dictionaries, string manipulation, and return statements.

# %% [markdown]
# #### Prerequisites

# %% [markdown]
# In order to complete this project, you should have completed the Loops and Dictionaries sections of the [Learn Python 3 Course](https://www.codecademy.com/learn/learn-python-3). This content is also covered in the [Data Scientist Career Path](https://www.codecademy.com/learn/paths/data-science/).

# %% [markdown]
# ## Project Requirements

# %% [markdown]
# 1. Hurricanes, also known as cyclones or typhoons, are one of the most powerful forces of nature on Earth. Due to climate change caused by human activity, the number and intensity of hurricanes has risen, calling for better preparation by the many communities that are devastated by them. As a concerned environmentalist, you want to look at data about the most powerful hurricanes that have occured.
#
#    Begin by looking at the `damages` list. The list contains strings representing the total cost in USD(`$`) caused by `34` category 5 hurricanes (wind speeds $\ge$ 157 mph (252 km/h)) in the Atlantic region. For some of the hurricanes, damage data was not recorded (`"Damages not recorded"`), while the rest are written in the format `"Prefix-B/M"`, where `B` stands for billions (`1000000000`) and `M` stands for millions (`1000000`).
#
#    Write a function that returns a new list of updated damages where the recorded data is converted to float values and the missing data is retained as `"Damages not recorded"`.
#
#    Test your function with the data stored in `damages`.

# %%
# damages (USD($)) of hurricanes
damages = ['Damages not recorded', '100M', 'Damages not recorded', '40M',
          '27.9M', '5M', 'Damages not recorded', '306M', '2M', '65.8M',
          '326M', '60.3M', '208M', '1.42B', '25.4M', 'Damages not recorded',
          '1.54B', '1.24B', '7.1B', '10B', '26.5B', '6.2B', '5.37B', '23.3B',
          '1.01B', '125B', '12B', '29.4B', '1.76B', '720M', '15.1B', '64.8B',
          '91.6B', '25.1B']

# 1
# Update Recorded Damages
conversion = {"M": 1000000,
             "B": 1000000000}
def records_to_float(list: list, conversion: str) -> list:
    
    new_list = [(float(data[:-1])*conversion[data[-1]]) if data[-1] in conversion else data for data in list ]
    return new_list
# test function by updating damages
updated_damages = records_to_float(damages,conversion)
print(updated_damages)
# Out:
# ['Damages not recorded', 100000000.0, 'Damages not recorded', 40000000.0, 27900000.0, 5000000.0, 'Damages not recorded', 306000000.0, 2000000.0, 65800000.0, 326000000.0, 60300000.0, 208000000.0, 1420000000.0, 25400000.0, 'Damages not recorded', 1540000000.0, 1240000000.0, 7100000000.0, 10000000000.0, 26500000000.0, 6200000000.0, 5370000000.0, 23300000000.0, 1010000000.0, 125000000000.0, 12000000000.0, 29400000000.0, 1760000000.0, 720000000.0, 15100000000.0, 64800000000.0, 91600000000.0, 25100000000.0]

# %% [markdown]
# 2. Additional data collected on the `34` strongest Atlantic hurricanes are provided in a series of lists. The data includes:
#    - `names`: names of the hurricanes
#    - `months`: months in which the hurricanes occurred
#    - `years`: years in which the hurricanes occurred
#    - `max_sustained_winds`: maximum sustained winds (miles per hour) of the hurricanes
#    - `areas_affected`: list of different areas affected by each of the hurricanes
#    - `deaths`: total number of deaths caused by each of the hurricanes
#
#    The data is organized such that the data at each index, from `0` to `33`, corresponds to the same hurricane.
#
#    For example, `names[0]` yields the "Cuba I" hurricane, which occurred in `months[0]` (October) `years[0]` (1924).
#
#    Write a function that constructs a dictionary made out of the lists, where the keys of the dictionary are the names of the hurricanes, and the values are dictionaries themselves containing a key for each piece of data (`Name`, `Month`, `Year`, `Max Sustained Wind`, `Areas Affected`, `Damage`, `Death`) about the hurricane.
#
#    Thus the key `"Cuba I"` would have the value: `{'Name': 'Cuba I', 'Month': 'October', 'Year': 1924, 'Max Sustained Wind': 165, 'Areas Affected': ['Central America', 'Mexico', 'Cuba', 'Florida', 'The Bahamas'], 'Damage': 'Damages not recorded', 'Deaths': 90}`.
#
#    Test your function on the lists of data provided.

# %%
# names of hurricanes
names = ['Cuba I', 'San Felipe II Okeechobee', 'Bahamas', 'Cuba II', 'CubaBrownsville', 'Tampico', 'Labor Day', 'New England', 'Carol', 'Janet', 'Carla', 'Hattie', 'Beulah', 'Camille', 'Edith', 'Anita', 'David', 'Allen', 'Gilbert', 'Hugo', 'Andrew', 'Mitch', 'Isabel', 'Ivan', 'Emily', 'Katrina', 'Rita', 'Wilma', 'Dean', 'Felix', 'Matthew', 'Irma', 'Maria', 'Michael']

# months of hurricanes
months = ['October', 'September', 'September', 'November', 'August', 'September', 'September', 'September', 'September', 'September', 'September', 'October', 'September', 'August', 'September', 'September', 'August', 'August', 'September', 'September', 'August', 'October', 'September', 'September', 'July', 'August', 'September', 'October', 'August', 'September', 'October', 'September', 'September', 'October']

# years of hurricanes
years = [1924, 1928, 1932, 1932, 1933, 1933, 1935, 1938, 1953, 1955, 1961, 1961, 1967, 1969, 1971, 1977, 1979, 1980, 1988, 1989, 1992, 1998, 2003, 2004, 2005, 2005, 2005, 2005, 2007, 2007, 2016, 2017, 2017, 2018]

# maximum sustained winds (mph) of hurricanes
max_sustained_winds = [165, 160, 160, 175, 160, 160, 185, 160, 160, 175, 175, 160, 160, 175, 160, 175, 175, 190, 185, 160, 175, 180, 165, 165, 160, 175, 180, 185, 175, 175, 165, 180, 175, 160]

# areas affected by each hurricane
areas_affected = [['Central America', 'Mexico', 'Cuba', 'Florida', 'The Bahamas'], ['Lesser Antilles', 'The Bahamas', 'United States East Coast', 'Atlantic Canada'], ['The Bahamas', 'Northeastern United States'], ['Lesser Antilles', 'Jamaica', 'Cayman Islands', 'Cuba', 'The Bahamas', 'Bermuda'], ['The Bahamas', 'Cuba', 'Florida', 'Texas', 'Tamaulipas'], ['Jamaica', 'Yucatn Peninsula'], ['The Bahamas', 'Florida', 'Georgia', 'The Carolinas', 'Virginia'], ['Southeastern United States', 'Northeastern United States', 'Southwestern Quebec'], ['Bermuda', 'New England', 'Atlantic Canada'], ['Lesser Antilles', 'Central America'], ['Texas', 'Louisiana', 'Midwestern United States'], ['Central America'], ['The Caribbean', 'Mexico', 'Texas'], ['Cuba', 'United States Gulf Coast'], ['The Caribbean', 'Central America', 'Mexico', 'United States Gulf Coast'], ['Mexico'], ['The Caribbean', 'United States East coast'], ['The Caribbean', 'Yucatn Peninsula', 'Mexico', 'South Texas'], ['Jamaica', 'Venezuela', 'Central America', 'Hispaniola', 'Mexico'], ['The Caribbean', 'United States East Coast'], ['The Bahamas', 'Florida', 'United States Gulf Coast'], ['Central America', 'Yucatn Peninsula', 'South Florida'], ['Greater Antilles', 'Bahamas', 'Eastern United States', 'Ontario'], ['The Caribbean', 'Venezuela', 'United States Gulf Coast'], ['Windward Islands', 'Jamaica', 'Mexico', 'Texas'], ['Bahamas', 'United States Gulf Coast'], ['Cuba', 'United States Gulf Coast'], ['Greater Antilles', 'Central America', 'Florida'], ['The Caribbean', 'Central America'], ['Nicaragua', 'Honduras'], ['Antilles', 'Venezuela', 'Colombia', 'United States East Coast', 'Atlantic Canada'], ['Cape Verde', 'The Caribbean', 'British Virgin Islands', 'U.S. Virgin Islands', 'Cuba', 'Florida'], ['Lesser Antilles', 'Virgin Islands', 'Puerto Rico', 'Dominican Republic', 'Turks and Caicos Islands'], ['Central America', 'United States Gulf Coast (especially Florida Panhandle)']]

# damages (USD($)) of hurricanes
damages = ['Damages not recorded', '100M', 'Damages not recorded', '40M', '27.9M', '5M', 'Damages not recorded', '306M', '2M', '65.8M', '326M', '60.3M', '208M', '1.42B', '25.4M', 'Damages not recorded', '1.54B', '1.24B', '7.1B', '10B', '26.5B', '6.2B', '5.37B', '23.3B', '1.01B', '125B', '12B', '29.4B', '1.76B', '720M', '15.1B', '64.8B', '91.6B', '25.1B']

# deaths for each hurricane
deaths = [90,4000,16,3103,179,184,408,682,5,1023,43,319,688,259,37,11,2068,269,318,107,65,19325,51,124,17,1836,125,87,45,133,603,138,3057,74]

# 2
# Create a Table
def create_table(keys:list ,**args:tuple)-> dict:
    table = {key:{} for key in keys}
    #print(table)
    #print(args)
    for i in range(len(names)):
        for key in args.keys():
            table[names[i]][key] = args[key][i]
    print("\n")
    print(table)
    return table
# Create and view the hurricanes dictionary
hurricane_dict = create_table(names, Name = names, Month=months, Year = years, Max_sustained_wind= max_sustained_winds, Area_affected= areas_affected, Damage=damages, Deaths = deaths)
# Out:
# {'Cuba I': {'Name': 'Cuba I', 'Month': 'October', 'Year': 1924, 'Max_sustained_wind': 165, 'Area_affected': ['Central America', 'Mexico', 'Cuba', 'Florida', 'The Bahamas'], 'Damage': 'Damages not recorded', 'Deaths': 90}, 'San Felipe II Okeechobee': {'Name': 'San Felipe II Okeechobee', 'Month': 'September', 'Year': 1928, 'Max_sustained_wind': 160, 'Area_affected': ['Lesser Antilles', 'The Bahamas', 'United States East Coast', 'Atlantic Canada'], 'Damage': '100M', 'Deaths': 4000}, 'Bahamas': {'Name': 'Bahamas', 'Month': 'September', 'Year': 1932, 'Max_sustained_wind': 160, 'Area_affected': ['The Bahamas', 'Northeastern United States'], 'Damage': 'Damages not recorded', 'Deaths': 16}, 'Cuba II': {'Name': 'Cuba II', 'Month': 'November', 'Year': 1932, 'Max_sustained_wind': 175, 'Area_affected': ['Lesser Antilles', 'Jamaica', 'Cayman Islands', 'Cuba', 'The Bahamas', 'Bermuda'], 'Damage': '40M', 'Deaths': 3103}, 'CubaBrownsville': {'Name': 'CubaBrownsville', 'Month': 'August', 'Year': 1933, 'Max_sustained_wind': 160, 'Area_affected': ['The Bahamas', 'Cuba', 'Florida', 'Texas', 'Tamaulipas'], 'Damage': '27.9M', 'Deaths': 179}, 'Tampico': {'Name': 'Tampico', 'Month': 'September', 'Year': 1933, 'Max_sustained_wind': 160, 'Area_affected': ['Jamaica', 'Yucatn Peninsula'], 'Damage': '5M', 'Deaths': 184}, 'Labor Day': {'Name': 'Labor Day', 'Month': 'September', 'Year': 1935, 'Max_sustained_wind': 185, 'Area_affected': ['The Bahamas', 'Florida', 'Georgia', 'The Carolinas', 'Virginia'], 'Damage': 'Damages not recorded', 'Deaths': 408}, 'New England': {'Name': 'New England', 'Month': 'September', 'Year': 1938, 'Max_sustained_wind': 160, 'Area_affected': ['Southeastern United States', 'Northeastern United States', 'Southwestern Quebec'], 'Damage': '306M', 'Deaths': 682}, 'Carol': {'Name': 'Carol', 'Month': 'September', 'Year': 1953, 'Max_sustained_wind': 160, 'Area_affected': ['Bermuda', 'New England', 'Atlantic Canada'], 'Damage': '2M', 'Deaths': 5}, 'Janet': {'Name': 'Janet', 'Month': 'September', 'Year': 1955, 'Max_sustained_wind': 175, 'Area_affected': ['Lesser Antilles', 'Central America'], 'Damage': '65.8M', 'Deaths': 1023}, 'Carla': {'Name': 'Carla', 'Month': 'September', 'Year': 1961, 'Max_sustained_wind': 175, 'Area_affected': ['Texas', 'Louisiana', 'Midwestern United States'], 'Damage': '326M', 'Deaths': 43}, 'Hattie': {'Name': 'Hattie', 'Month': 'October', 'Year': 1961, 'Max_sustained_wind': 160, 'Area_affected': ['Central America'], 'Damage': '60.3M', 'Deaths': 319}, 'Beulah': {'Name': 'Beulah', 'Month': 'September', 'Year': 1967, 'Max_sustained_wind': 160, 'Area_affected': ['The Caribbean', 'Mexico', 'Texas'], 'Damage': '208M', 'Deaths': 688}, 'Camille': {'Name': 'Camille', 'Month': 'August', 'Year': 1969, 'Max_sustained_wind': 175, 'Area_affected': ['Cuba', 'United States Gulf Coast'], 'Damage': '1.42B', 'Deaths': 259}, 'Edith': {'Name': 'Edith', 'Month': 'September', 'Year': 1971, 'Max_sustained_wind': 160, 'Area_affected': ['The Caribbean', 'Central America', 'Mexico', 'United States Gulf Coast'], 'Damage': '25.4M', 'Deaths': 37}, 'Anita': {'Name': 'Anita', 'Month': 'September', 'Year': 1977, 'Max_sustained_wind': 175, 'Area_affected': ['Mexico'], 'Damage': 'Damages not recorded', 'Deaths': 11}, 'David': {'Name': 'David', 'Month': 'August', 'Year': 1979, 'Max_sustained_wind': 175, 'Area_affected': ['The Caribbean', 'United States East coast'], 'Damage': '1.54B', 'Deaths': 2068}, 'Allen': {'Name': 'Allen', 'Month': 'August', 'Year': 1980, 'Max_sustained_wind': 190, 'Area_affected': ['The Caribbean', 'Yucatn Peninsula', 'Mexico', 'South Texas'], 'Damage': '1.24B', 'Deaths': 269}, 'Gilbert': {'Name': 'Gilbert', 'Month': 'September', 'Year': 1988, 'Max_sustained_wind': 185, 'Area_affected': ['Jamaica', 'Venezuela', 'Central America', 'Hispaniola', 'Mexico'], 'Damage': '7.1B', 'Deaths': 318}, 'Hugo': {'Name': 'Hugo', 'Month': 'September', 'Year': 1989, 'Max_sustained_wind': 160, 'Area_affected': ['The Caribbean', 'United States East ...

# %%
test_dict = {}
test_dict.update({"key":"value 1"})
print(test_dict)
test_dict.update({"key":"value 2"})
print(test_dict)
# Out:
# {'key': 'value 1'}
# {'key': 'value 2'}

# %%
YEAR = set()

for key in hurricane_dict.keys():
    #print(hurricane_dict[key]["Year"])
    
    YEAR.add(hurricane_dict[key]["Year"])
    if hurricane_dict[key]["Year"] == 1933:
        print(hurricane_dict[key])
        print(hurricane_dict[key]["Year"])
print(YEAR)
# Out:
# {'Name': 'CubaBrownsville', 'Month': 'August', 'Year': 1933, 'Max_sustained_wind': 160, 'Area_affected': ['The Bahamas', 'Cuba', 'Florida', 'Texas', 'Tamaulipas'], 'Damage': '27.9M', 'Deaths': 179}
# 1933
# {'Name': 'Tampico', 'Month': 'September', 'Year': 1933, 'Max_sustained_wind': 160, 'Area_affected': ['Jamaica', 'Yucatn Peninsula'], 'Damage': '5M', 'Deaths': 184}
# 1933
# {1924, 1928, 1932, 1933, 1935, 1938, 1953, 1955, 1961, 1967, 1969, 1971, 1977, 1979, 1980, 1988, 1989, 1992, 1998, 2003, 2004, 2005, 2007, 2016, 2017, 2018}

# %%
def query_groupby(dict:dict, groupby_key)-> dict:
    new_keys = set()
    for key in dict.keys():
        new_keys.add(dict[key][groupby_key])
    print(new_keys)
    new_dict ={}
    for new_key in new_keys:
        new_dict[new_key] = []
   #for value in new_keys:
    for new_key in new_keys:
        print("\n\n")
        print("new_key is:", new_key)

        for key in dict.keys():
            print("dict[key][groupby_key] is: ", dict[key][groupby_key])
            print(f"{new_key} == {dict[key][groupby_key]} is True? ", new_key == dict[key][groupby_key])
            if new_key == dict[key][groupby_key]:
                print("we are in")
                new_dict[new_key].append(dict[key])
            
    print("the dict is: ",new_dict)
    return new_dict

hurricanes_by_year = query_groupby(hurricane_dict,"Year")
# Out:
# {1924, 1928, 1932, 1933, 1935, 1938, 1953, 1955, 1961, 1967, 1969, 1971, 1977, 1979, 1980, 1988, 1989, 1992, 1998, 2003, 2004, 2005, 2007, 2016, 2017, 2018}
#
#
#
# new_key is: 1924
# dict[key][groupby_key] is:  1924
# 1924 == 1924 is True?  True
# we are in
# dict[key][groupby_key] is:  1928
# 1924 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 1924 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 1924 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 1924 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 1924 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 1924 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 1924 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 1924 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 1924 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 1924 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 1924 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 1924 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 1924 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 1924 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 1924 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 1924 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 1924 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 1924 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 1924 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 1924 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 1924 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 1924 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 1924 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 1924 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1924 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1924 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1924 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 1924 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 1924 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 1924 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 1924 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 1924 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 1924 == 2018 is True?  False
#
#
#
# new_key is: 1928
# dict[key][groupby_key] is:  1924
# 1928 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 1928 == 1928 is True?  True
# we are in
# dict[key][groupby_key] is:  1932
# 1928 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 1928 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 1928 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 1928 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 1928 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 1928 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 1928 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 1928 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 1928 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 1928 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 1928 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 1928 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 1928 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 1928 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 1928 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 1928 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 1928 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 1928 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 1928 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 1928 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 1928 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 1928 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 1928 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1928 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1928 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1928 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 1928 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 1928 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 1928 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 1928 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 1928 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 1928 == 2018 is True?  False
#
#
#
# new_key is: 1932
# dict[key][groupby_key] is:  1924
# 1932 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 1932 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 1932 == 1932 is True?  True
# we are in
# dict[key][groupby_key] is:  1932
# 1932 == 1932 is True?  True
# we are in
# dict[key][groupby_key] is:  1933
# 1932 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 1932 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 1932 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 1932 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 1932 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 1932 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 1932 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 1932 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 1932 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 1932 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 1932 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 1932 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 1932 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 1932 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 1932 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 1932 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 1932 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 1932 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 1932 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 1932 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 1932 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1932 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1932 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1932 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 1932 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 1932 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 1932 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 1932 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 1932 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 1932 == 2018 is True?  False
#
#
#
# new_key is: 1933
# dict[key][groupby_key] is:  1924
# 1933 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 1933 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 1933 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 1933 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 1933 == 1933 is True?  True
# we are in
# dict[key][groupby_key] is:  1933
# 1933 == 1933 is True?  True
# we are in
# dict[key][groupby_key] is:  1935
# 1933 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 1933 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 1933 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 1933 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 1933 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 1933 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 1933 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 1933 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 1933 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 1933 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 1933 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 1933 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 1933 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 1933 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 1933 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 1933 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 1933 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 1933 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 1933 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1933 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1933 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1933 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 1933 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 1933 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 1933 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 1933 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 1933 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 1933 == 2018 is True?  False
#
#
#
# new_key is: 1935
# dict[key][groupby_key] is:  1924
# 1935 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 1935 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 1935 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 1935 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 1935 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 1935 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 1935 == 1935 is True?  True
# we are in
# dict[key][groupby_key] is:  1938
# 1935 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 1935 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 1935 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 1935 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 1935 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 1935 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 1935 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 1935 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 1935 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 1935 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 1935 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 1935 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 1935 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 1935 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 1935 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 1935 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 1935 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 1935 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1935 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1935 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1935 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 1935 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 1935 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 1935 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 1935 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 1935 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 1935 == 2018 is True?  False
#
#
#
# new_key is: 1938
# dict[key][groupby_key] is:  1924
# 1938 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 1938 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 1938 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 1938 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 1938 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 1938 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 1938 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 1938 == 1938 is True?  True
# we are in
# dict[key][groupby_key] is:  1953
# 1938 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 1938 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 1938 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 1938 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 1938 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 1938 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 1938 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 1938 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 1938 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 1938 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 1938 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 1938 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 1938 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 1938 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 1938 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 1938 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 1938 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1938 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1938 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1938 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 1938 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 1938 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 1938 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 1938 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 1938 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 1938 == 2018 is True?  False
#
#
#
# new_key is: 1953
# dict[key][groupby_key] is:  1924
# 1953 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 1953 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 1953 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 1953 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 1953 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 1953 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 1953 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 1953 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 1953 == 1953 is True?  True
# we are in
# dict[key][groupby_key] is:  1955
# 1953 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 1953 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 1953 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 1953 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 1953 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 1953 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 1953 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 1953 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 1953 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 1953 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 1953 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 1953 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 1953 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 1953 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 1953 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 1953 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1953 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1953 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1953 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 1953 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 1953 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 1953 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 1953 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 1953 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 1953 == 2018 is True?  False
#
#
#
# new_key is: 1955
# dict[key][groupby_key] is:  1924
# 1955 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 1955 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 1955 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 1955 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 1955 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 1955 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 1955 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 1955 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 1955 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 1955 == 1955 is True?  True
# we are in
# dict[key][groupby_key] is:  1961
# 1955 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 1955 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 1955 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 1955 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 1955 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 1955 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 1955 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 1955 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 1955 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 1955 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 1955 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 1955 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 1955 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 1955 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 1955 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1955 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1955 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1955 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 1955 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 1955 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 1955 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 1955 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 1955 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 1955 == 2018 is True?  False
#
#
#
# new_key is: 1961
# dict[key][groupby_key] is:  1924
# 1961 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 1961 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 1961 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 1961 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 1961 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 1961 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 1961 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 1961 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 1961 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 1961 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 1961 == 1961 is True?  True
# we are in
# dict[key][groupby_key] is:  1961
# 1961 == 1961 is True?  True
# we are in
# dict[key][groupby_key] is:  1967
# 1961 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 1961 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 1961 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 1961 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 1961 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 1961 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 1961 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 1961 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 1961 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 1961 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 1961 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 1961 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 1961 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1961 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1961 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1961 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 1961 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 1961 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 1961 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 1961 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 1961 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 1961 == 2018 is True?  False
#
#
#
# new_key is: 1967
# dict[key][groupby_key] is:  1924
# 1967 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 1967 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 1967 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 1967 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 1967 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 1967 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 1967 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 1967 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 1967 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 1967 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 1967 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 1967 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 1967 == 1967 is True?  True
# we are in
# dict[key][groupby_key] is:  1969
# 1967 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 1967 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 1967 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 1967 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 1967 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 1967 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 1967 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 1967 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 1967 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 1967 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 1967 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 1967 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1967 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1967 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1967 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 1967 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 1967 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 1967 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 1967 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 1967 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 1967 == 2018 is True?  False
#
#
#
# new_key is: 1969
# dict[key][groupby_key] is:  1924
# 1969 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 1969 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 1969 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 1969 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 1969 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 1969 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 1969 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 1969 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 1969 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 1969 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 1969 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 1969 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 1969 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 1969 == 1969 is True?  True
# we are in
# dict[key][groupby_key] is:  1971
# 1969 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 1969 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 1969 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 1969 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 1969 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 1969 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 1969 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 1969 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 1969 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 1969 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 1969 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1969 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1969 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1969 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 1969 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 1969 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 1969 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 1969 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 1969 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 1969 == 2018 is True?  False
#
#
#
# new_key is: 1971
# dict[key][groupby_key] is:  1924
# 1971 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 1971 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 1971 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 1971 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 1971 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 1971 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 1971 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 1971 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 1971 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 1971 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 1971 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 1971 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 1971 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 1971 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 1971 == 1971 is True?  True
# we are in
# dict[key][groupby_key] is:  1977
# 1971 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 1971 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 1971 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 1971 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 1971 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 1971 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 1971 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 1971 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 1971 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 1971 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1971 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1971 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1971 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 1971 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 1971 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 1971 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 1971 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 1971 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 1971 == 2018 is True?  False
#
#
#
# new_key is: 1977
# dict[key][groupby_key] is:  1924
# 1977 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 1977 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 1977 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 1977 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 1977 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 1977 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 1977 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 1977 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 1977 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 1977 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 1977 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 1977 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 1977 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 1977 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 1977 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 1977 == 1977 is True?  True
# we are in
# dict[key][groupby_key] is:  1979
# 1977 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 1977 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 1977 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 1977 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 1977 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 1977 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 1977 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 1977 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 1977 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1977 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1977 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1977 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 1977 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 1977 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 1977 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 1977 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 1977 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 1977 == 2018 is True?  False
#
#
#
# new_key is: 1979
# dict[key][groupby_key] is:  1924
# 1979 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 1979 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 1979 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 1979 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 1979 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 1979 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 1979 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 1979 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 1979 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 1979 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 1979 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 1979 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 1979 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 1979 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 1979 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 1979 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 1979 == 1979 is True?  True
# we are in
# dict[key][groupby_key] is:  1980
# 1979 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 1979 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 1979 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 1979 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 1979 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 1979 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 1979 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 1979 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1979 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1979 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1979 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 1979 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 1979 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 1979 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 1979 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 1979 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 1979 == 2018 is True?  False
#
#
#
# new_key is: 1980
# dict[key][groupby_key] is:  1924
# 1980 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 1980 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 1980 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 1980 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 1980 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 1980 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 1980 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 1980 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 1980 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 1980 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 1980 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 1980 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 1980 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 1980 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 1980 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 1980 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 1980 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 1980 == 1980 is True?  True
# we are in
# dict[key][groupby_key] is:  1988
# 1980 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 1980 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 1980 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 1980 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 1980 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 1980 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 1980 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1980 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1980 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1980 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 1980 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 1980 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 1980 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 1980 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 1980 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 1980 == 2018 is True?  False
#
#
#
# new_key is: 1988
# dict[key][groupby_key] is:  1924
# 1988 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 1988 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 1988 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 1988 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 1988 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 1988 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 1988 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 1988 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 1988 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 1988 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 1988 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 1988 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 1988 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 1988 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 1988 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 1988 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 1988 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 1988 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 1988 == 1988 is True?  True
# we are in
# dict[key][groupby_key] is:  1989
# 1988 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 1988 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 1988 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 1988 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 1988 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 1988 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1988 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1988 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1988 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 1988 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 1988 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 1988 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 1988 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 1988 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 1988 == 2018 is True?  False
#
#
#
# new_key is: 1989
# dict[key][groupby_key] is:  1924
# 1989 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 1989 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 1989 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 1989 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 1989 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 1989 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 1989 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 1989 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 1989 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 1989 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 1989 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 1989 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 1989 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 1989 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 1989 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 1989 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 1989 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 1989 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 1989 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 1989 == 1989 is True?  True
# we are in
# dict[key][groupby_key] is:  1992
# 1989 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 1989 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 1989 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 1989 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 1989 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1989 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1989 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1989 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 1989 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 1989 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 1989 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 1989 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 1989 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 1989 == 2018 is True?  False
#
#
#
# new_key is: 1992
# dict[key][groupby_key] is:  1924
# 1992 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 1992 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 1992 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 1992 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 1992 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 1992 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 1992 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 1992 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 1992 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 1992 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 1992 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 1992 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 1992 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 1992 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 1992 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 1992 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 1992 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 1992 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 1992 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 1992 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 1992 == 1992 is True?  True
# we are in
# dict[key][groupby_key] is:  1998
# 1992 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 1992 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 1992 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 1992 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1992 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1992 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1992 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 1992 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 1992 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 1992 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 1992 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 1992 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 1992 == 2018 is True?  False
#
#
#
# new_key is: 1998
# dict[key][groupby_key] is:  1924
# 1998 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 1998 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 1998 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 1998 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 1998 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 1998 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 1998 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 1998 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 1998 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 1998 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 1998 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 1998 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 1998 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 1998 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 1998 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 1998 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 1998 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 1998 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 1998 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 1998 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 1998 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 1998 == 1998 is True?  True
# we are in
# dict[key][groupby_key] is:  2003
# 1998 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 1998 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 1998 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1998 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1998 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 1998 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 1998 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 1998 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 1998 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 1998 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 1998 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 1998 == 2018 is True?  False
#
#
#
# new_key is: 2003
# dict[key][groupby_key] is:  1924
# 2003 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 2003 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 2003 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 2003 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 2003 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 2003 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 2003 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 2003 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 2003 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 2003 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 2003 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 2003 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 2003 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 2003 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 2003 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 2003 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 2003 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 2003 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 2003 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 2003 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 2003 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 2003 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 2003 == 2003 is True?  True
# we are in
# dict[key][groupby_key] is:  2004
# 2003 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 2003 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 2003 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 2003 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 2003 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 2003 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 2003 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 2003 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 2003 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 2003 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 2003 == 2018 is True?  False
#
#
#
# new_key is: 2004
# dict[key][groupby_key] is:  1924
# 2004 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 2004 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 2004 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 2004 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 2004 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 2004 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 2004 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 2004 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 2004 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 2004 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 2004 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 2004 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 2004 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 2004 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 2004 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 2004 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 2004 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 2004 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 2004 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 2004 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 2004 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 2004 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 2004 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 2004 == 2004 is True?  True
# we are in
# dict[key][groupby_key] is:  2005
# 2004 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 2004 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 2004 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 2004 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 2004 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 2004 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 2004 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 2004 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 2004 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 2004 == 2018 is True?  False
#
#
#
# new_key is: 2005
# dict[key][groupby_key] is:  1924
# 2005 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 2005 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 2005 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 2005 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 2005 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 2005 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 2005 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 2005 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 2005 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 2005 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 2005 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 2005 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 2005 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 2005 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 2005 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 2005 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 2005 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 2005 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 2005 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 2005 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 2005 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 2005 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 2005 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 2005 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 2005 == 2005 is True?  True
# we are in
# dict[key][groupby_key] is:  2005
# 2005 == 2005 is True?  True
# we are in
# dict[key][groupby_key] is:  2005
# 2005 == 2005 is True?  True
# we are in
# dict[key][groupby_key] is:  2005
# 2005 == 2005 is True?  True
# we are in
# dict[key][groupby_key] is:  2007
# 2005 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 2005 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 2005 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 2005 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 2005 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 2005 == 2018 is True?  False
#
#
#
# new_key is: 2007
# dict[key][groupby_key] is:  1924
# 2007 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 2007 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 2007 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 2007 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 2007 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 2007 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 2007 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 2007 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 2007 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 2007 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 2007 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 2007 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 2007 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 2007 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 2007 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 2007 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 2007 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 2007 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 2007 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 2007 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 2007 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 2007 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 2007 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 2007 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 2007 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 2007 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 2007 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 2007 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 2007 == 2007 is True?  True
# we are in
# dict[key][groupby_key] is:  2007
# 2007 == 2007 is True?  True
# we are in
# dict[key][groupby_key] is:  2016
# 2007 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 2007 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 2007 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 2007 == 2018 is True?  False
#
#
#
# new_key is: 2016
# dict[key][groupby_key] is:  1924
# 2016 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 2016 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 2016 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 2016 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 2016 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 2016 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 2016 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 2016 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 2016 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 2016 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 2016 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 2016 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 2016 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 2016 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 2016 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 2016 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 2016 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 2016 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 2016 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 2016 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 2016 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 2016 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 2016 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 2016 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 2016 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 2016 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 2016 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 2016 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 2016 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 2016 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 2016 == 2016 is True?  True
# we are in
# dict[key][groupby_key] is:  2017
# 2016 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 2016 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 2016 == 2018 is True?  False
#
#
#
# new_key is: 2017
# dict[key][groupby_key] is:  1924
# 2017 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 2017 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 2017 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 2017 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 2017 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 2017 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 2017 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 2017 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 2017 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 2017 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 2017 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 2017 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 2017 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 2017 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 2017 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 2017 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 2017 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 2017 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 2017 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 2017 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 2017 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 2017 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 2017 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 2017 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 2017 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 2017 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 2017 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 2017 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 2017 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 2017 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 2017 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 2017 == 2017 is True?  True
# we are in
# dict[key][groupby_key] is:  2017
# 2017 == 2017 is True?  True
# we are in
# dict[key][groupby_key] is:  2018
# 2017 == 2018 is True?  False
#
#
#
# new_key is: 2018
# dict[key][groupby_key] is:  1924
# 2018 == 1924 is True?  False
# dict[key][groupby_key] is:  1928
# 2018 == 1928 is True?  False
# dict[key][groupby_key] is:  1932
# 2018 == 1932 is True?  False
# dict[key][groupby_key] is:  1932
# 2018 == 1932 is True?  False
# dict[key][groupby_key] is:  1933
# 2018 == 1933 is True?  False
# dict[key][groupby_key] is:  1933
# 2018 == 1933 is True?  False
# dict[key][groupby_key] is:  1935
# 2018 == 1935 is True?  False
# dict[key][groupby_key] is:  1938
# 2018 == 1938 is True?  False
# dict[key][groupby_key] is:  1953
# 2018 == 1953 is True?  False
# dict[key][groupby_key] is:  1955
# 2018 == 1955 is True?  False
# dict[key][groupby_key] is:  1961
# 2018 == 1961 is True?  False
# dict[key][groupby_key] is:  1961
# 2018 == 1961 is True?  False
# dict[key][groupby_key] is:  1967
# 2018 == 1967 is True?  False
# dict[key][groupby_key] is:  1969
# 2018 == 1969 is True?  False
# dict[key][groupby_key] is:  1971
# 2018 == 1971 is True?  False
# dict[key][groupby_key] is:  1977
# 2018 == 1977 is True?  False
# dict[key][groupby_key] is:  1979
# 2018 == 1979 is True?  False
# dict[key][groupby_key] is:  1980
# 2018 == 1980 is True?  False
# dict[key][groupby_key] is:  1988
# 2018 == 1988 is True?  False
# dict[key][groupby_key] is:  1989
# 2018 == 1989 is True?  False
# dict[key][groupby_key] is:  1992
# 2018 == 1992 is True?  False
# dict[key][groupby_key] is:  1998
# 2018 == 1998 is True?  False
# dict[key][groupby_key] is:  2003
# 2018 == 2003 is True?  False
# dict[key][groupby_key] is:  2004
# 2018 == 2004 is True?  False
# dict[key][groupby_key] is:  2005
# 2018 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 2018 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 2018 == 2005 is True?  False
# dict[key][groupby_key] is:  2005
# 2018 == 2005 is True?  False
# dict[key][groupby_key] is:  2007
# 2018 == 2007 is True?  False
# dict[key][groupby_key] is:  2007
# 2018 == 2007 is True?  False
# dict[key][groupby_key] is:  2016
# 2018 == 2016 is True?  False
# dict[key][groupby_key] is:  2017
# 2018 == 2017 is True?  False
# dict[key][groupby_key] is:  2017
# 2018 == 2017 is True?  False
# dict[key][groupby_key] is:  2018
# 2018 == 2018 is True?  True
# we are in
# the dict is:  {1924: [{'Name': 'Cuba I', 'Month': 'October', 'Year': 1924, 'Max_sustained_wind': 165, 'Area_affected': ['Central America', 'Mexico', 'Cuba', 'Florida', 'The Bahamas'], 'Damage': 'Damages not recorded', 'Deaths': 90}], 1928: [{'Name': 'San Felipe II Okeechobee', 'Month': 'September', 'Year': 1928, 'Max_sustained_wind': 160, 'Area_affected': ['Lesser Antilles', 'The Bahamas', 'United States East Coast', 'Atlantic Canada'], 'Damage': '100M', 'Deaths': 4000}], 1932: [{'Name': 'Bahamas', 'Month': 'September', 'Year': 1932, 'Max_sustained_wind': 160, 'Area_affected': ['The Bahamas', 'Northeastern United States'], 'Damage': 'Damages not recorded', 'Deaths': 16}, {'Name': 'Cuba II', 'Month': 'November', 'Year': 1932, 'Max_sustained_wind': 175, 'Area_affected': ['Lesser Antilles', 'Jamaica', 'Cayman Islands', 'Cuba', 'The Bahamas', 'Bermuda'], 'Damage': '40M', 'Deaths': 3103}], 1933: [{'Name': 'CubaBrownsville', 'Month': 'August', 'Year': 1933, 'Max_sustained_wind': 160, 'Area_affected': ['The Bahamas', 'Cuba', 'Florida', 'Texas', 'Tamaulipas'], 'Damage': '27.9M', 'Deaths': 179}, {'Name': 'Tampico', 'Month': 'September', 'Year': 1933, 'Max_sustained_wind': 160, 'Area_affected': ['Jamaica', 'Yucatn Peninsula'], 'Damage': '5M', 'Deaths': 184}], 1935: [{'Name': 'Labor Day', 'Month': 'September', 'Year': 1935, 'Max_sustained_wind': 185, 'Area_affected': ['The Bahamas', 'Florida', 'Georgia', 'The Carolinas', 'Virginia'], 'Damage': 'Damages not recorded', 'Deaths': 408}], 1938: [{'Name': 'New England', 'Month': 'September', 'Year': 1938, 'Max_sustained_wind': 160, 'Area_affected': ['Southeastern United States', 'Northeastern United States', 'Southwestern Quebec'], 'Damage': '306M', 'Deaths': 682}], 1953: [{'Name': 'Carol', 'Month': 'September', 'Year': 1953, 'Max_sustained_wind': 160, 'Area_affected': ['Bermuda', 'New England', 'Atlantic Canada'], 'Damage': '2M', 'Deaths': 5}], 1955: [{'Name': 'Janet', 'Month': 'September', 'Year': 1955, 'Max_sustained_wind': 175, 'Area_affected': ['Lesser Antilles', 'Central America'], 'Damage': '65.8M', 'Deaths': 1023}], 1961: [{'Name': 'Carla', 'Month': 'September', 'Year': 1961, 'Max_sustained_wind': 175, 'Area_affected': ['Texas', 'Louisiana', 'Midwestern United States'], 'Damage': '326M', 'Deaths': 43}, {'Name': 'Hattie', 'Month': 'October', 'Year': 1961, 'Max_sustained_wind': 160, 'Area_affected': ['Central America'], 'Damage': '60.3M', 'Deaths': 319}], 1967: [{'Name': 'Beulah', 'Month': 'September', 'Year': 1967, 'Max_sustained_wind': 160, 'Area_affected': ['The Caribbean', 'Mexico', 'Texas'], 'Damage': '208M', 'Deaths': 688}], 1969: [{'Name': 'Camille', 'Month': 'August', 'Year': 1969, 'Max_sustained_wind': 175, 'Area_affected': ['Cuba', 'United States Gulf Coast'], 'Damage': '1.42B', 'Deaths': 259}], 1971: [{'Name': 'Edith', 'Month': 'September', 'Year': 1971, 'Max_sustained_wind': 160, 'Area_affected': ['The Caribbean', 'Central America', 'Mexico', 'United States Gulf Coast'], 'Damage': '25.4M', 'Deaths': 37}], 1977: [{'Name': 'Anita', 'Month': 'September', 'Year': 1977, 'Max_sustained_wind': 175, 'Area_affected': ['Mexico'], 'Damage': 'Damages not recorded', 'Deaths': 11}], 1979: [{'Name': 'David', 'Month': 'August', 'Year': 1979, 'Max_sustained_wind': 175, 'Area_affected': ['The Caribbean', 'United States East coast'], 'Damage': '1.54B', 'Deaths': 2068}], 1980: [{'Name': 'Allen', 'Month': 'August', 'Year': 1980, 'Max_sustained_wind': 190, 'Area_affected': ['The Caribbean', 'Yucatn Peninsula', 'Mexico', 'South Texas'], 'Damage': '1.24B', 'Deaths': 269}], 1988: [{'Name': 'Gilbert', 'Month': 'September', 'Year': 1988, 'Max_sustained_wind': 185, 'Area_affected': ['Jamaica', 'Venezuela', 'Central America', 'Hispaniola', 'Mexico'], 'Damage': '7.1B', 'Deaths': 318}], 1989: [{'Name': 'Hugo', 'Month': 'September', 'Year': 1989, 'Max_sustained_wind': 160, 'Area_affected': ['The Caribbean', 'United States East Coast'], 'Damage': '10B', 'Deaths': 107}], 1992: [{'Name': 'Andrew', 'Month': 'Au ...

# %%
print(hurricanes_by_year[1932])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 print(hurricanes_by_year[1932])
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# 3. In addition to organizing the hurricanes in a dictionary with names as the key, you want to be able to organize the hurricanes by year.
#
#    Write a function that converts the current dictionary of hurricanes to a new dictionary, where the keys are years and the values are lists containing a dictionary for each hurricane that occurred in that year.
#
#    For example, the key `1932` would yield the value: `[{'Name': 'Bahamas', 'Month': 'September', 'Year': 1932, 'Max Sustained Wind': 160, 'Areas Affected': ['The Bahamas', 'Northeastern United States'], 'Damage': 'Damage not recorded', 'Deaths': 16}, {'Name': 'Cuba II', 'Month': 'November', 'Year': 1932, 'Max Sustained Wind': 175, 'Areas Affected': ['Lesser Antilles', 'Jamaica', 'Cayman Islands', 'Cuba', 'The Bahamas', 'Bermuda'], 'Damage': 40000000.0, 'Deaths': 3103}]`.
#
#    Test your function on your hurricane dictionary.

# %%
# 3
# Organizing by Year
def query_groupby(dict:dict, key)-> dict:
    
    
# create a new dictionary of hurricanes with year and key
# Out:
#   Cell In[68], line 6
#     # create a new dictionary of hurricanes with year and key
#                                                              ^
# SyntaxError: incomplete input

# %% [markdown]
# 4. You believe that knowing how often each of the areas of the Atlantic are affected by these strong hurricanes is important for making preparations for future hurricanes.
#
#    Write a function that counts how often each area is listed as an affected area of a hurricane. Store and return the results in a dictionary where the keys are the affected areas and the values are counts of how many times the areas were affected.
#
#    Test your function on your hurricane dictionary.

# %%
# 4
# Counting Damaged Areas

# create dictionary of areas to store the number of hurricanes involved in

# %% [markdown]
# 5. Write a function that finds the area affected by the most hurricanes, and how often it was hit.
#
#    Test your function on your affected area dictionary.

# %%
# 5
# Calculating Maximum Hurricane Count

# find most frequently affected area and the number of hurricanes involved in

# %% [markdown]
# 6. Write a function that finds the hurricane that caused the greatest number of deaths, and how many deaths it caused.
#
#    Test your function on your hurricane dictionary.

# %%
# 6
# Calculating the Deadliest Hurricane

# find highest mortality hurricane and the number of deaths

# %% [markdown]
# 7. Just as hurricanes are rated by their windspeed, you want to try rating hurricanes based on other metrics.
#
#    Write a function that rates hurricanes on a mortality scale according to the following ratings, where the key is the rating and the value is the upper bound of deaths for that rating.
#
#    ```py
#    mortality_scale = {0: 0,
#    1: 100,
#    2: 500,
#    3: 1000,
#    4: 10000}
#    ```
#
#    For example, a hurricane with a `1` mortality rating would have resulted in greater than `0` but less than or equal to `100` deaths. A hurricane with a `5` mortality would have resulted in greater than `10000` deaths.
#
#    Store the hurricanes in a new dictionary where the keys are the mortaility ratings and the values are lists containing a dictionary for each hurricane that falls into that mortality rating.
#
#    Test your function on your hurricane dictionary.

# %%
# 7
# Rating Hurricanes by Mortality

# categorize hurricanes in new dictionary with mortality severity as key

# %% [markdown]
# 8. Write a function that finds the hurricane that caused the greatest damage, and how costly it was.
#
#    Test your function on your hurricane dictionary.

# %%
# 8
# Calculating Hurricane Maximum Damage

# find highest damage inducing hurricane and its total cost

# %% [markdown]
# 9. Lastly, you want to rate hurricanes according to how much damage they cause.
#
#    Write a function that rates hurricanes on a damage scale according to the following ratings, where the key is the rating and the value is the upper bound of damage for that rating.
#    ```py
#    damage_scale = {0: 0,
#    1: 100000000,
#    2: 1000000000,
#    3: 10000000000,
#    4: 50000000000}
#    ```
#
#    For example, a hurricane with a `1` damage rating would have resulted in damages greater than `0` USD but less than or equal to `100000000` USD. A hurricane with a `5` damage rating would have resulted in damages greater than `50000000000` USD (talk about a lot of money).
#
#    Store the hurricanes in a new dictionary where the keys are damage ratings and the values are lists containing a dictionary for each hurricane that falls into that damage rating.
#
#    Test your function on your hurricane dictionary.

# %%
# 9
# Rating Hurricanes by Damage
damage_scale = {0: 0,
                1: 100000000,
                2: 1000000000,
                3: 10000000000,
                4: 50000000000}

# categorize hurricanes in new dictionary with damage severity as key

# %% [markdown]
# ## Solution

# %% [markdown]
# Great work! View the **Hurricane Analysis_Solution.ipynb** file or visit [our forums](https://discuss.codecademy.com/t/hurricane-analysis-challenge-project-python/462363) to compare your project to our sample solution code. You can also learn how to host your own solution on GitHub so you can share it with other learners! Your solution might look different than ours, and that's okay! There are multiple ways to solve these projects, and you'll learn more by seeing others' code.
